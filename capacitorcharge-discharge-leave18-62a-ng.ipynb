# %% [markdown]
# # My Practical
#
# ## Aims
#
# To plot graphs of the Voltage against time across a capacitor when discharging and charging.
#
# $$ V = V_{0} e^{-t/RC} $$
#
# ### Risk Assesment
#
# There is a risk when we discharged the capacitor rapidly, we made sure not to make contact with the metal and we touched the two ends together. Furthermore, the Capacitor has a high voltage so we did not in any way expose ourselves to the circuit.
#
#
# ### Experimental Method
# [image not shared with don --ACN]
# [img src="Image.jpg" height="150" width="150" /]
# 1. Design a single circuit to investigate the charging and discharging of a capacitor.
# 2. Choosing the values of R 100K and C 0.001F to get a time constant of 100s allowed a complete set of results to be obtained within a
# reasonable time (i.e. repeats are not required)
# 3. Plot the charge and discharge curves for the voltages against time on the same graph.
#
# #### Apparatus
#
# capacitors 1000 µF
# resistor
# voltmeter
# 6 V battery pack
# SPDT (single pole, double throw) switch
# stopclock
# leads
#
#
# # Analysis
#
# Our results showed that there was indeed a clear pattern between the Voltage of a capacitor over time when charging and discharging, which clearly followed the equation V=Vo*e^-t/RC. The increase of the Voltage was exponential when charging and was exponential decay when charging.
#
# [image not shared with don --ACN]
# [img src="capcircuit.jpg" height="150" width="150" /]
#
# | Heading | Heading |
# | -------| ------|
# | 3.45 | 2.45 |

# %%
#
# Paste the data you wish to graph in tab-delimited rows in the format:
#
#       xdata <tab> ydata
#
# In this example the xdata is time (s) and y data is y position (cm)
#

data = """
0	220
1	182
2	144
3	118
4	96
5	78
6	67
7	52
8	46
9	38
10	36
11	31
12	25
13	15
14	13
15	9
16	3

""".split('\n')  # split this string on the "newline" character.

#print len(data)


#
# The data is stored in a single string. Now, split the data and store
# each column in a list. Convert the data from a string to a float.
#
tlist = []
ylist = []

for s in data:
    if s:
        t,y = s.split()     # split the string in two
        t=float(t)          # convert time to float
        y=float(y)/100.0    # convert y-position (cm) to float in meters
        tlist.append(t)     # append to the list for time data
        ylist.append(y)     # append to the list for y-position data
        
#print "tlist=",tlist
#print "ylist=",ylist

import matplotlib.pyplot as plt
plt.title('Voltage against time for a Capacitor')
plt.xlabel('t (s)')
plt.ylabel('V (V)')
plt.plot(tlist,ylist,'m.')
plt.show()

# %%
#
# Paste the data you wish to graph in tab-delimited rows in the format:
#
#       xdata <tab> ydata
#
# In this example the xdata is time (s) and y data is y position (cm)
#

data = """
0 5.5
5 5.36
10 5.18
15 4.94
20 4.72
25 4.49
30 4.31
35 4.14
40 3.95
45 3.79
50 3.61
55 3.46
60 3.31
65 3.15
70 3.04
75 2.89
80 2.77
85 2.64
90 2.53
95 2.41
100 2.32
105 2.23
110 2.13
115 2.04
120 1.95
125 1.87
130 1.8
135 1.71
140 1.64
145 1.57
150 1.5
155 1.44
160 1.38
165 1.31
170 1.26
175 1.21
180 1.16
185 1.11
190 1.06
195 1.02
200 0.97
205 0.94
210 0.9
215 0.85
220 0.82
225 0.78
230 0.75
235 0.72
240 0.69
245 0.66
250 0.63
255 0.61
260 0.58
265 0.56
270 0.54
275 0.51
280 0.49
285 0.47
290 0.45
295 0.43
300 0.41
305 0.4
310 0.38
315 0.36
320 0.35
325 0.33
330 0.32
335 0.31
340 0.3
345 0.28
350 0.27
355 0.26
360 0.25
0 0
5 0.23
10 0.5
15 0.71
20 0.93
25 1.12
30 1.34
35 1.5
40 1.69
45 1.86
50 2.03
55 2.19
60 2.34
65 2.48
70 2.62
75 2.74
80 2.87
85 2.99
90 3.1
95 3.22
100 3.32
105 3.41
110 3.5
115 3.6
120 3.69
125 3.77
130 3.85
135 3.93
140 4
145 4.07
150 4.14
155 4.2
160 4.26
165 4.32
170 4.39
175 4.43
180 4.49
185 4.53
190 4.58
195 4.63
200 4.66
205 4.7
210 4.75
215 4.78
220 4.82
225 4.85
230 4.88
235 4.92
240 4.95
245 4.98
250 5.01
255 5.03
260 5.06
265 5.09
270 5.1
275 5.13
280 5.15
285 5.17
290 5.19
295 5.21
300 5.23
305 5.25
310 5.26
315 5.28
320 5.29
325 5.3
330 5.32
335 5.34
340 5.35
345 5.36
350 5.37
355 5.38
360 5.39
""".split('\n')  # split this string on the "newline" character.

#print len(data)


#
# The data is stored in a single string. Now, split the data and store
# each column in a list. Convert the data from a string to a float.
#
tlist = []
ylist = []

for s in data:
    if s:
        t,y = s.split()     # split the string in two
        t=float(t)          # convert time to float
        y=float(y)/100.0    # convert y-position (cm) to float in meters
        tlist.append(t)     # append to the list for time data
        ylist.append(y)     # append to the list for y-position data
        
#print "tlist=",tlist
#print "ylist=",ylist

import matplotlib.pyplot as plt
plt.title('Discharging/Charging of a Capacitor')
plt.xlabel('time (s)')
plt.ylabel('Voltage (V)')
plt.plot(tlist,ylist,'m.')
plt.show()
